# %% [markdown]
# #Import Libraries and Load Dataset

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from transformers import BertTokenizer, BertModel
import torch
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import warnings
warnings.filterwarnings("ignore")

# %%
# Load the cleaned dataset
file_path = "combined_cleaned_dataset.csv"  # Update with your file name
combined_df = pd.read_csv(file_path)

# %%
combined_df.head()
# Out:
#        ID         Name               Role  \
# 0  uppaup  alice smith  software engineer
# 1  uppaup   hank brown  software engineer
# 2  uppaup    bob jones     data scientist
# 3  uppaup   bob miller  software engineer
# 4  uppaup    ivy jones      data engineer
#
#                                           Transcript  \
# 0  heres a simulated interview for a software eng...
# 1  heres a simulated interview for a software eng...
# 2  heres a simulated interview for a data scienti...
# 3  heres a simulated interview for a software eng...
# 4  heres a simulated interview for a data enginee...
#
#                                               Resume  decision  \
# 0  heres a sample resume for alice smith\n\nalice...  rejected
# 1  heres a resume for hank brown a selected candi...  selected
# 2  heres a sample resume for bob jones who applie...  rejected
# 3  heres a sample resume for bob miller a softwar...  selected
# 4  heres a sample resume for ivy jones\n\nivy jon...  rejected
#
#                                 Reason for decision  \
# 0     unsatisfactory references or background check
# 1                   growth mindset and adaptability
# 2  inadequate communication or interpersonal skills
# 3                               strong cultural fit
# 4             lack of relevant skills or experience
#
#                                      Job Description  Transcript_length  \
# 0  here is a comprehensive job description for a ...               3101
# 1  here is a job description for a software engin...               4965
# 2  here is a comprehensive job description for a ...               2803
# 3  here is a sample job description for a softwar...               4119
# 4  here is a sample job description for a data en...               3321
#
#    Resume_length  Job_Description_length  Transcript_Resume_Score  \
# 0           2599                    3857                 0.128843
# 1           2634                    1066                 0.268331
# 2           3050                    3105                 0.311734
# 3           2491                    3354                 0.226898
# 4           2864                    3843                 0.361991
#
#    Transcript_JobDescription_Score  Resume_JobDescription_Score  \
# 0                         0.159541                     0.267942
# 1                         0.190271                     0.268425
# 2                         0.285505                     0.466292
# 3                         0.259491                     0.326965
# 4                         0.420489                     0.588236
#
#    Final_Match_Score
# 0           0.185442
# 1           0.242342
# 2           0.354511
# 3           0.271118
# 4           0.456905

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3174 entries, 0 to 3173
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               3174 non-null   object
#  1   Name                             3174 non-null   object
#  2   Role                             3174 non-null   object
#  3   Transcript                       3174 non-null   object
#  4   Resume                           3174 non-null   object
#  5   decision                         3174 non-null   object
#  6   Reason for decision              3174 non-null   object
#  7   Job Description                  3174 non-null   object
#  8   Transcript_length                3174 non-null   int64
#  9   Resume_length                    3174 non-null   int64
#  10  Job_Description_length           3174 non-null   int64
#  11  Transcript_Resume_Score          3174 non-null   float64
#  12  Transcript_JobDescription_Score  3174 non-null   float64
#  13  Resume_JobDescription_Score      3174 non-null   float64
#  14  Final_Match_Score                3174 non-null   float64
# dtypes: float64(4), int64(3), object(8)
# memory usage: 372.1+ KB

# %% [markdown]
# #Generate BERT Embeddings

# %%
# Initialize BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = BertModel.from_pretrained('bert-base-uncased')
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %% [markdown]
# #Purpose:
#  Initializes the BERT tokenizer and model for generating embeddings.
# #Explanation:
# BertTokenizer is used to tokenize the text data.
#
# BertModel is the pre-trained BERT model that will be used to generate embeddings.

# %%
def get_bert_embeddings(text_column):
    """
    Generate BERT embeddings for a given text column.
    """
    embeddings = []
    for text in text_column:
        inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=128)
        outputs = bert_model(**inputs)
        cls_embedding = outputs.last_hidden_state[:, 0, :].detach().numpy()
        embeddings.append(cls_embedding.flatten())
    return np.array(embeddings)

# %% [markdown]
# #Bert Embeddings for Transcript

# %%
# Generate embeddings
combined_df['Transcript_embeddings'] = list(get_bert_embeddings(combined_df['Transcript']))

# %% [markdown]
# #Bert Embeddings for Resume

# %%
combined_df['Resume_embeddings'] = list(get_bert_embeddings(combined_df['Resume']))

# %% [markdown]
# #Bert Embeddings for Job_Description

# %%
combined_df['Job_Description_embeddings'] = list(get_bert_embeddings(combined_df['Job Description']))

# %%
combined_df.head()
# Out:
#        ID         Name               Role  \
# 0  uppaup  alice smith  software engineer
# 1  uppaup   hank brown  software engineer
# 2  uppaup    bob jones     data scientist
# 3  uppaup   bob miller  software engineer
# 4  uppaup    ivy jones      data engineer
#
#                                           Transcript  \
# 0  heres a simulated interview for a software eng...
# 1  heres a simulated interview for a software eng...
# 2  heres a simulated interview for a data scienti...
# 3  heres a simulated interview for a software eng...
# 4  heres a simulated interview for a data enginee...
#
#                                               Resume  decision  \
# 0  heres a sample resume for alice smith\n\nalice...  rejected
# 1  heres a resume for hank brown a selected candi...  selected
# 2  heres a sample resume for bob jones who applie...  rejected
# 3  heres a sample resume for bob miller a softwar...  selected
# 4  heres a sample resume for ivy jones\n\nivy jon...  rejected
#
#                                 Reason for decision  \
# 0     unsatisfactory references or background check
# 1                   growth mindset and adaptability
# 2  inadequate communication or interpersonal skills
# 3                               strong cultural fit
# 4             lack of relevant skills or experience
#
#                                      Job Description  Transcript_length  \
# 0  here is a comprehensive job description for a ...               3101
# 1  here is a job description for a software engin...               4965
# 2  here is a comprehensive job description for a ...               2803
# 3  here is a sample job description for a softwar...               4119
# 4  here is a sample job description for a data en...               3321
#
#    Resume_length  Job_Description_length  Transcript_Resume_Score  \
# 0           2599                    3857                 0.128843
# 1           2634                    1066                 0.268331
# 2           3050                    3105                 0.311734
# 3           2491                    3354                 0.226898
# 4           2864                    3843                 0.361991
#
#    Transcript_JobDescription_Score  Resume_JobDescription_Score  \
# 0                         0.159541                     0.267942
# 1                         0.190271                     0.268425
# 2                         0.285505                     0.466292
# 3                         0.259491                     0.326965
# 4                         0.420489                     0.588236
#
#    Final_Match_Score                              Transcript_embeddings  \
# 0           0.185442  [-0.12769948, 0.23564614, -0.24298234, -0.1760...
# 1           0.242342  [-0.40148726, 0.009195297, -0.2979158, -0.1014...
# 2           0.354511  [-0.3487926, 0.020128839, -0.2336443, -0.16934...
# 3           0.271118  [-0.5011333, 0.124364235, -0.27339292, -0.0982...
# 4           0.456905  [-0.2763126, 0.10006799, -0.15044409, -0.14078...
#
#                                    Resume_embeddings  \
# 0  [-0.60704345, 0.21568073, -0.24985889, -0.1235...
# 1  [-0.9606815, -0.13537142, -0.20789696, -0.1510...
# 2  [-0.9852158, -0.068383835, 0.0065283687, -0.18...
# 3  [-0.7354975, 0.3179848, -0.035682846, -0.12026...
# 4  [-0.6419997, 0.09423823, 0.046364304, 0.057823...
#
#                           Job_Description_embeddings
# 0  [-0.5358736, -0.48269117, 0.21164827, -0.26815...
# 1  [-0.14280689, -0.18455483, -0.14317629, 0.2373...
# 2  [-0.63903207, -0.117160745, 0.24371581, 0.2260...
# 3  [-0.7920371, 0.15553382, -0.26356754, 0.256035...
# 4  [-0.60751843, 0.102332525, 0.26001558, 0.10051...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3174 entries, 0 to 3173
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               3174 non-null   object
#  1   Name                             3174 non-null   object
#  2   Role                             3174 non-null   object
#  3   Transcript                       3174 non-null   object
#  4   Resume                           3174 non-null   object
#  5   decision                         3174 non-null   object
#  6   Reason for decision              3174 non-null   object
#  7   Job Description                  3174 non-null   object
#  8   Transcript_length                3174 non-null   int64
#  9   Resume_length                    3174 non-null   int64
#  10  Job_Description_length           3174 non-null   int64
#  11  Transcript_Resume_Score          3174 non-null   float64
#  12  Transcript_JobDescription_Score  3174 non-null   float64
#  13  Resume_JobDescription_Score      3174 non-null   float64
#  14  Final_Match_Score                3174 non-null   float64
#  15  Transcript_embeddings            3174 non-null   object
#  16  Resume_embeddings                3174 non-null   object
#  17  Job_Description_embeddings       3174 non-null   object
# dtypes: float64(4), int64(3), object(11)
# memory usage: 446.5+ KB

# %%
# Assuming 'data' is your pandas DataFrame
unique_decisions = combined_df['decision'].unique()
print("Unique values in 'decision' column:", unique_decisions)
# Out:
# Unique values in 'decision' column: ['rejected' 'selected' 'reject' 'select']

# %%
# Assuming 'data' is your pandas DataFrame
combined_df['decision'] = combined_df['decision'].replace({'select': 'selected', 'reject': 'rejected'})

# %%
# Assuming 'data' is your pandas DataFrame
unique_decisions = combined_df['decision'].unique()
print("Unique values in 'decision' column:", unique_decisions)
# Out:
# Unique values in 'decision' column: ['rejected' 'selected']

# %% [markdown]
# #Combine Features and Train-Test Split

# %%
# Combine embeddings and features
handcrafted_features = ['Transcript_length', 'Resume_length', 'Job_Description_length']
X_embeddings = np.hstack([
    np.vstack(df['Transcript_embeddings']),
    np.vstack(df['Resume_embeddings']),
    np.vstack(df['Job_Description_embeddings']),
    combined_df[handcrafted_features].values
])

# %%
# Encode target variable
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(df['decision'])

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_embeddings, y, test_size=0.2, random_state=42, stratify=y)

# %%
print(np.unique(y_test))
# Out:
# [0 1]

# %% [markdown]
# #Random Forest Model

# %%
# Train Random Forest
rf = RandomForestClassifier(random_state=42, n_estimators=100)
rf.fit(X_train, y_train)

# Evaluate Random Forest
y_pred_rf = rf.predict(X_test)
y_prob_rf = rf.predict_proba(X_test)[:, 1]

print("Random Forest - Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Random Forest - ROC AUC Score:", roc_auc_score(y_test, y_prob_rf))
# Out:
# Random Forest - Accuracy: 0.7984251968503937
# Random Forest - ROC AUC Score: 0.9120363939436033

# %% [markdown]
# #Artificial Neural Network (ANN)

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam

# Define ANN model
ann = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

# %%
# Compile the ANN
ann.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the ANN
history = ann.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7890 - loss: 0.3806 - val_accuracy: 0.8031 - val_loss: 0.3234
# Epoch 2/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8085 - loss: 0.3359 - val_accuracy: 0.8268 - val_loss: 0.3127
# Epoch 3/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8047 - loss: 0.3454 - val_accuracy: 0.8287 - val_loss: 0.3124
# Epoch 4/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8126 - loss: 0.3297 - val_accuracy: 0.8307 - val_loss: 0.3057
# Epoch 5/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8272 - loss: 0.3149 - val_accuracy: 0.8130 - val_loss: 0.3690
# Epoch 6/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7755 - loss: 0.3782 - val_accuracy: 0.8051 - val_loss: 0.3251
# Epoch 7/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7800 - loss: 0.3637 - val_accuracy: 0.8209 - val_loss: 0.3345
# Epoch 8/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8005 - loss: 0.3372 - val_accuracy: 0.7874 - val_loss: 0.4057
# Epoch 9/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7971 - loss: 0.3974 - val_accuracy: 0.8287 - val_loss: 0.3367
# Epoch 10/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7749 - loss: 0.3721 - val_accuracy: 0.8346 - val_loss: 0.3144
# Epoch 11/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7807 - loss: 0.3616 - val_accuracy: 0.8268 - val_loss: 0.3159
# Epoch 12/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7922 - loss: 0.3330 - val_accuracy: 0.8169 - val_loss: 0.3865
# Epoch 13/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7934 - loss: 0.3616 - val_accuracy: 0.8287 - val_loss: 0.3271
# Epoch 14/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7971 - loss: 0.3419 - val_accuracy: 0.8268 - val_loss: 0.3465
# Epoch 15/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7912 - loss: 0.3664 - val_accuracy: 0.8071 - val_loss: 0.3148
# Epoch 16/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8013 - loss: 0.3554 - val_accuracy: 0.7992 - val_loss: 0.3105
# Epoch 17/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7935 - loss: 0.3363 - val_accuracy: 0.7874 - val_loss: 0.3342
# Epoch 18/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8043 - loss: 0.3583 - val_accuracy: 0.8130 - val_loss: 0.3274
# Epoch 19/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8016 - loss: 0.3396 - val_accuracy: 0.8327 - val_loss: 0.3246
# Epoch 20/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7982 - loss: 0.3484 - val_accuracy: 0.8110 - val_loss: 0.3173
# Epoch 21/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8027 - loss: 0.3422 - val_accuracy: 0.8091 - val_loss: 0.3188
# Epoch 22/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7951 - loss: 0.3337 - val_accuracy: 0.8366 - val_loss: 0.3133
# Epoch 23/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7924 - loss: 0.3512 - val_accuracy: 0.8091 - val_loss: 0.3306
# Epoch 24/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7946 - loss: 0.3476 - val_accuracy: 0.8386 - val_loss: 0.3175
# Epoch 25/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8191 - loss: 0.3239 - val_accuracy: 0.8248 - val_loss: 0.3388
# Epoch 26/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8018 - loss: 0.3320 - val_accuracy: 0.8307 - val_loss: 0.3313
# Epoch 27/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7903 - loss: 0.3404 - val_accuracy: 0.8406 - val_loss: 0.3189
# Epoch 28/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7748 - loss: 0.3502 - val_accuracy: 0.7874 - val_loss: 0.3993
# Epoch 29/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7760 - loss: 0.3500 - val_accuracy: 0.8012 - val_loss: 0.3172
# Epoch 30/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7815 - loss: 0.3387 - val_accuracy: 0.8327 - val_loss: 0.3095
# Epoch 31/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7998 - loss: 0.3221 - val_accuracy: 0.8386 - val_loss: 0.3165
# Epoch 32/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7729 - loss: 0.3591 - val_accuracy: 0.8425 - val_loss: 0.3137
# Epoch 33/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7878 - loss: 0.3427 - val_accuracy: 0.8366 - val_loss: 0.3156
# Epoch 34/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7827 - loss: 0.3458 - val_accuracy: 0.8248 - val_loss: 0.3915
# Epoch 35/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7803 - loss: 0.3613 - val_accuracy: 0.8484 - val_loss: 0.3122
# Epoch 36/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7924 - loss: 0.3621 - val_accuracy: 0.8346 - val_loss: 0.3184
# Epoch 37/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7875 - loss: 0.3327 - val_accuracy: 0.8366 - val_loss: 0.3227
# Epoch 38/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7957 - loss: 0.3466 - val_accuracy: 0.8425 - val_loss: 0.3238
# Epoch 39/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7958 - loss: 0.3218 - val_accuracy: 0.8406 - val_loss: 0.3270
# Epoch 40/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7883 - loss: 0.3276 - val_accuracy: 0.8445 - val_loss: 0.3173
# Epoch 41/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7787 - loss: 0.3544 - val_accuracy: 0.8366 - val_loss: 0.3163
# Epoch 42/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8129 - loss: 0.3103 - val_accuracy: 0.8445 - val_loss: 0.3289
# Epoch 43/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8068 - loss: 0.3084 - val_accuracy: 0.8543 - val_loss: 0.3140
# Epoch 44/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7809 - loss: 0.3353 - val_accuracy: 0.8425 - val_loss: 0.3250
# Epoch 45/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7696 - loss: 0.3255 - val_accuracy: 0.8425 - val_loss: 0.3225
# Epoch 46/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8098 - loss: 0.3083 - val_accuracy: 0.8268 - val_loss: 0.3235
# Epoch 47/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7925 - loss: 0.3201 - val_accuracy: 0.8465 - val_loss: 0.3081
# Epoch 48/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7982 - loss: 0.3099 - val_accuracy: 0.8406 - val_loss: 0.3098
# Epoch 49/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7890 - loss: 0.3403 - val_accuracy: 0.8386 - val_loss: 0.3205
# Epoch 50/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7971 - loss: 0.3107 - val_accuracy: 0.8268 - val_loss: 0.3471
# Epoch 51/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7966 - loss: 0.3547 - val_accuracy: 0.8406 - val_loss: 0.3176
# Epoch 52/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8198 - loss: 0.2999 - val_accuracy: 0.8071 - val_loss: 0.3163
# Epoch 53/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7982 - loss: 0.3228 - val_accuracy: 0.8150 - val_loss: 0.3056
# Epoch 54/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8040 - loss: 0.3104 - val_accuracy: 0.8209 - val_loss: 0.3045
# Epoch 55/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8017 - loss: 0.3139 - val_accuracy: 0.8031 - val_loss: 0.3274
# Epoch 56/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7844 - loss: 0.3534 - val_accuracy: 0.8287 - val_loss: 0.3416
# Epoch 57/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7929 - loss: 0.3354 - val_accuracy: 0.8406 - val_loss: 0.3034
# Epoch 58/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8033 - loss: 0.3082 - val_accuracy: 0.8406 - val_loss: 0.3152
# Epoch 59/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8090 - loss: 0.2985 - val_accuracy: 0.8465 - val_loss: 0.3092
# Epoch 60/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8090 - loss: 0.3238 - val_accuracy: 0.8110 - val_loss: 0.4495
# Epoch 61/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8003 - loss: 0.3259 - val_accuracy: 0.8071 - val_loss: 0.3094
# Epoch 62/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7859 - loss: 0.3316 - val_accuracy: 0.8169 - val_loss: 0.3130
# Epoch 63/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7825 - loss: 0.3416 - val_accuracy: 0.8051 - val_loss: 0.3542
# Epoch 64/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8033 - loss: 0.3157 - val_accuracy: 0.8169 - val_loss: 0.3219
# Epoch 65/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8125 - loss: 0.3199 - val_accuracy: 0.8130 - val_loss: 0.3156
# Epoch 66/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8062 - loss: 0.3196 - val_accuracy: 0.8209 - val_loss: 0.3078
# Epoch 67/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8192 - loss: 0.2992 - val_accuracy: 0.7972 - val_loss: 0.3341
# Epoch 68/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7852 - loss: 0.3372 - val_accuracy: 0.8110 - val_loss: 0.3056
# Epoch 69/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8079 - loss: 0.3143 - val_accuracy: 0.8169 - val_loss: 0.3090
# Epoch 70/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7934 - loss: 0.3197 - val_accuracy: 0.8051 - val_loss: 0.3065
# Epoch 71/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8024 - loss: 0.3231 - val_accuracy: 0.8366 - val_loss: 0.3224
# Epoch 72/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7968 - loss: 0.3285 - val_accuracy: 0.8366 - val_loss: 0.3155
# Epoch 73/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8079 - loss: 0.3015 - val_accuracy: 0.8465 - val_loss: 0.3192
# Epoch 74/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7985 - loss: 0.3316 - val_accuracy: 0.8012 - val_loss: 0.3287
# Epoch 75/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7979 - loss: 0.3220 - val_accuracy: 0.8307 - val_loss: 0.3313
# Epoch 76/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8029 - loss: 0.3244 - val_accuracy: 0.8031 - val_loss: 0.3106
# Epoch 77/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8128 - loss: 0.3217 - val_accuracy: 0.8091 - val_loss: 0.3157
# Epoch 78/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8121 - loss: 0.3110 - val_accuracy: 0.8091 - val_loss: 0.3558
# Epoch 79/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8239 - loss: 0.3020 - val_accuracy: 0.8031 - val_loss: 0.3104
# Epoch 80/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8053 - loss: 0.3133 - val_accuracy: 0.8031 - val_loss: 0.3089
# Epoch 81/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8028 - loss: 0.3141 - val_accuracy: 0.7795 - val_loss: 0.3724
# Epoch 82/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8019 - loss: 0.3226 - val_accuracy: 0.7933 - val_loss: 0.3301
# Epoch 83/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7743 - loss: 0.3322 - val_accuracy: 0.8189 - val_loss: 0.3151
# Epoch 84/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8201 - loss: 0.2957 - val_accuracy: 0.8071 - val_loss: 0.3140
# Epoch 85/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8172 - loss: 0.3091 - val_accuracy: 0.7972 - val_loss: 0.3181
# Epoch 86/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8204 - loss: 0.3083 - val_accuracy: 0.7913 - val_loss: 0.3290
# Epoch 87/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7988 - loss: 0.3001 - val_accuracy: 0.8091 - val_loss: 0.3222
# Epoch 88/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8048 - loss: 0.2904 - val_accuracy: 0.8228 - val_loss: 0.3643
# Epoch 89/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8037 - loss: 0.3112 - val_accuracy: 0.8110 - val_loss: 0.3196
# Epoch 90/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7987 - loss: 0.3042 - val_accuracy: 0.8031 - val_loss: 0.3194
# Epoch 91/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8124 - loss: 0.3082 - val_accuracy: 0.7953 - val_loss: 0.3834
# Epoch 92/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7766 - loss: 0.3392 - val_accuracy: 0.8091 - val_loss: 0.3149
# Epoch 93/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8006 - loss: 0.3092 - val_accuracy: 0.8130 - val_loss: 0.3044
# Epoch 94/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8228 - loss: 0.3011 - val_accuracy: 0.8150 - val_loss: 0.3047
# Epoch 95/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8028 - loss: 0.3399 - val_accuracy: 0.8189 - val_loss: 0.3353
# Epoch 96/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8143 - loss: 0.3075 - val_accuracy: 0.8031 - val_loss: 0.3062
# Epoch 97/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8152 - loss: 0.2972 - val_accuracy: 0.8110 - val_loss: 0.3048
# Epoch 98/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8057 - loss: 0.2998 - val_accuracy: 0.8110 - val_loss: 0.3165
# Epoch 99/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8072 - loss: 0.3022 - val_accuracy: 0.8189 - val_loss: 0.3147
# Epoch 100/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7949 - loss: 0.3194 - val_accuracy: 0.8209 - val_loss: 0.3283

# %%
# Evaluate the ANN
y_prob_ann = ann.predict(X_test).flatten()
y_pred_ann = (y_prob_ann > 0.5).astype(int)

print("ANN - Accuracy:", accuracy_score(y_test, y_pred_ann))
print("ANN - ROC AUC Score:", roc_auc_score(y_test, y_prob_ann))
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ANN - Accuracy: 0.8251968503937008
# ANN - ROC AUC Score: 0.9303127418490663

# %% [markdown]
# #Combine Random Forest and ANN Predictions

# %%
# Combine predictions from ANN and Random Forest
combined_predictions = (y_prob_rf + y_prob_ann) / 2
combined_pred_labels = (combined_predictions > 0.5).astype(int)

# Evaluate combined model
print("Combined Model - Accuracy:", accuracy_score(y_test, combined_pred_labels))
print("Combined Model - ROC AUC Score:", roc_auc_score(y_test, combined_predictions))
# Out:
# Combined Model - Accuracy: 0.8062992125984252
# Combined Model - ROC AUC Score: 0.9314339293155796

# %%
# Save the combined dataset with embeddings for future use
df.to_csv("combined_dataset_with_embeddings.csv", index=False)
print("Dataset with embeddings saved as 'combined_dataset_with_embeddings.xlsx'")
# Out:
# Dataset with embeddings saved as 'combined_dataset_with_embeddings.xlsx'
